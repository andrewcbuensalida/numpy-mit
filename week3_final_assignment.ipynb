# %% [markdown]
# # Codio Coding Assignment 3.1: Pandas Foundations, Data Cleaning, and Manipulation
#
# ### Learning Outcomes Addressed
#
# - 2. Implement pandas *series* and *dataframes*.
# - 3. Perform data cleaning in pandas.
# - 4. Prepare data using one-hot encoding in pandas.
# - 7. Analyze data in pandas.
# - 8. Design *dataframes* in pandas.
#
#
# ## Index:
#
# - [Question 1](#Question-1)
# - [Question 2](#Question-2)
# - [Question 3](#Question-3)
# - [Question 4](#Question-4)
# - [Question 5](#Question-5)
# - [Question 6](#Question-6)
# - [Question 7](#Question-7)
# - [Question 8](#Question-8)
# - [Question 9](#Question-9)
# - [Question 10](#Question-10)
# - [Question 11](#Question-11)
# - [Question 12](#Question-12)
# - [Question 13](#Question-13)
# - [Question 14](#Question-14)
# - [Question 15](#Question-15)
# - [Question 16](#Question-16)
# - [Question 17](#Question-17)

# %% [markdown]
# ### Importing Pandas
#
# Before you begin this activity, you need to import the *pandas library*.
#
# Run the code cell below:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Question 1
#
# *3 points*
#
# Create a `pandas` *dataframe, `df,`* containing three columns named *`id, name,`* and *`last_name`* and the values listed in the table below:
#
# | id | name  | last_name |
# |----|-------|-----------|
# | 1  | Peter | Homs      |
# | 2  | James | Miller    |
# | 3  | Mark  | Huldi     |

# %%
data = {
    "id": [1, 2, 3],
    "name": ["Peter", "James", "Mark"],
    "last_name": ["Homs", "Miller", "Huldi"],
}

df = pd.DataFrame(data)
df
# Out:
#    id   name last_name
# 0   1  Peter      Homs
# 1   2  James    Miller
# 2   3   Mark     Huldi

# %% [markdown]
# ## Question 2
#
# *3 points*
#
# Consider the *dataframe, `df,`* from Question 1. Select the column `name` and assign it to a variable called *`ans2a`*.
#
# What is the type of *`ans2a`*? Assign your result to *`ans2b.`*

# %%
### GRADED
### YOUR SOLUTION HERE
ans2a = df['name']
ans2b = type(ans2a)

ans2b
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Question 3
#
# *5 points*
#
# Consider the *dataframe, `df,`* from Question 1. Change `name` column to `Name` and `last_name` column to `Last_Name`.

# %%
df.rename(columns={'name': 'Name','last_name':"Last_Name"}, inplace=True)

# %% [markdown]
# ## Question 4
#
# *4 points*
#
# Read the .csv file `"data.csv"` inside the `data` folder and assign it to a *dataframe* called *`df_4`*.
#
# Group by the column *`season`* and count how many times each feature appears in each season. Assign the solution to the *dataframe `df_4_grouped`*.

# %%
### GRADED
### YOUR SOLUTION HERE
df_4 = pd.read_csv('data/data.csv')
df_4_grouped = df_4.groupby('season').count()

# %% [markdown]
# Run the code cell below to visualize the first five rows of your *dataframe*.

# %%
df_4.head()
# Out:
#               datetime  season  holiday  workingday  weather      temp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.843750
# 1  2011-01-01 01:00:00       1        0           0        1  9.023438
# 2  2011-01-01 02:00:00       1        0           0        1  9.023438
# 3  2011-01-01 03:00:00       1        0           0        1  9.843750
# 4  2011-01-01 04:00:00       1        0           0        1  9.843750
#
#        atemp  humidity  windspeed  casual  registered  count  hour  year  \
# 0  14.398438        81        0.0       3          13     16     0  2011
# 1  13.632812        80        0.0       8          32     40     1  2011
# 2  13.632812        80        0.0       5          27     32     2  2011
# 3  14.398438        75        0.0       3          10     13     3  2011
# 4  14.398438        75        0.0       0           1      1     4  2011
#
#    month weather_label
# 0      1         Clear
# 1      1         Clear
# 2      1         Clear
# 3      1         Clear
# 4      1         Clear

# %% [markdown]
# ## Question 5
#
# *5 points*
#
# Consider the  *dataframe `df_4`* from Question 4.  Create a filter to get all the rows where the column `humidity` is less than or equal to 85. Assign the new *dataframe* to *`ans5a`*.

# %%
### GRADED
### YOUR SOLUTION HERE
filter_5 = df_4['humidity'] <= 85
ans5a = df_4[filter_5]
ans5a
# Out:
#                   datetime  season  holiday  workingday  weather       temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.843750
# 1      2011-01-01 01:00:00       1        0           0        1   9.023438
# 2      2011-01-01 02:00:00       1        0           0        1   9.023438
# 3      2011-01-01 03:00:00       1        0           0        1   9.843750
# 4      2011-01-01 04:00:00       1        0           0        1   9.843750
# ...                    ...     ...      ...         ...      ...        ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.578125
# 10882  2012-12-19 20:00:00       4        0           1        1  14.757812
# 10883  2012-12-19 21:00:00       4        0           1        1  13.937500
# 10884  2012-12-19 22:00:00       4        0           1        1  13.937500
# 10885  2012-12-19 23:00:00       4        0           1        1  13.117188
#
#            atemp  humidity  windspeed  casual  registered  count  hour  year  \
# 0      14.398438        81   0.000000       3          13     16     0  2011
# 1      13.632812        80   0.000000       8          32     40     1  2011
# 2      13.632812        80   0.000000       5          27     32     2  2011
# 3      14.398438        75   0.000000       3          10     13     3  2011
# 4      14.398438        75   0.000000       0           1      1     4  2011
# ...          ...       ...        ...     ...         ...    ...   ...   ...
# 10881  19.687500        50  26.000000       7         329    336    19  2012
# 10882  17.421875        57  15.000000      10         231    241    20  2012
# 10883  15.906250        61  15.000000       4         164    168    21  2012
# 10884  17.421875        61   6.003906      12         117    129    22  2012
# 10885  16.671875        66   9.000000       4          84     88    23  2012
#
#        month weather_label
# 0          1         Clear
# 1          1         Clear
# 2          1         Clear
# 3          1         Clear
# 4          1         Clear
# ...      ...           ...
# 10881     12         Clear
# 10882     12         Clear
# 10883     12         Clear
# 10884     12         Clear
# 10885     12         Clear
#
# [9353 rows x 16 columns]

# %% [markdown]
# ## Question 6
#
# *4 points*
#
# Consider the  *dataframe `df_4`* from Question 4. Create a filter to get all the rows where the column `atemp` is greater than or equal to 15. Assign this new *dataframe* to *`ans6a`*.

# %%
### GRADED
### YOUR SOLUTION HERE
filter_6 = df_4['atemp'] >= 15
ans6a = df_4[filter_6]
ans6a
# Out:
#                   datetime  season  holiday  workingday  weather       temp  \
# 9      2011-01-01 09:00:00       1        0           0        1  13.117188
# 10     2011-01-01 10:00:00       1        0           0        1  15.578125
# 11     2011-01-01 11:00:00       1        0           0        1  14.757812
# 12     2011-01-01 12:00:00       1        0           0        1  17.218750
# 13     2011-01-01 13:00:00       1        0           0        2  18.859375
# ...                    ...     ...      ...         ...      ...        ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.578125
# 10882  2012-12-19 20:00:00       4        0           1        1  14.757812
# 10883  2012-12-19 21:00:00       4        0           1        1  13.937500
# 10884  2012-12-19 22:00:00       4        0           1        1  13.937500
# 10885  2012-12-19 23:00:00       4        0           1        1  13.117188
#
#            atemp  humidity  windspeed  casual  registered  count  hour  year  \
# 9      17.421875        76   0.000000       8           6     14     9  2011
# 10     19.687500        76  17.000000      12          24     36    10  2011
# 11     16.671875        81  19.000000      26          30     56    11  2011
# 12     21.203125        77  19.000000      29          55     84    12  2011
# 13     22.718750        72  20.000000      47          47     94    13  2011
# ...          ...       ...        ...     ...         ...    ...   ...   ...
# 10881  19.687500        50  26.000000       7         329    336    19  2012
# 10882  17.421875        57  15.000000      10         231    241    20  2012
# 10883  15.906250        61  15.000000       4         164    168    21  2012
# 10884  17.421875        61   6.003906      12         117    129    22  2012
# 10885  16.671875        66   9.000000       4          84     88    23  2012
#
#        month weather_label
# 9          1         Clear
# 10         1         Clear
# 11         1         Clear
# 12         1         Clear
# 13         1          Mist
# ...      ...           ...
# 10881     12         Clear
# 10882     12         Clear
# 10883     12         Clear
# 10884     12         Clear
# 10885     12         Clear
#
# [8924 rows x 16 columns]

# %% [markdown]
# ## Question 7
#
# *5 points*
#
# Consider the *dataframe `df_4`*. Compute the average of the column *`windspeed`* and assign the value to the variable *`ans7a`*.
#
# **HINT:** For this question, use the *function [mean()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html).*

# %%
### GRADED
### YOUR SOLUTION HERE
ans7a = df_4['windspeed'].mean()
ans7a
# Out:
# 12.799412663053463

# %% [markdown]
# ## Question 8
#
# *6 points*
#
# Create a *pandas dataframe, `df_8`*, containing five columns named `name, age, gender, state, and num_pets` and the following values:
#
# | name | age| gender|state|num_pets |
# |------|----|-------|-----|---------|
# | john | 23 | M     |california|5|
# | mary | 78 | F     |dc|1|
# | peter| 22 | M     |california|0|
# |jeff  |19 | M     |dc|5|
# |bill  |45  | M     |dc|2|
# |lisa  |33  | NaN     |california|2|
# |jose|20|M|texas|3
#
# You can use the provided lists to avoid typing errors.
#
# Next, sort the column age in descending order and assign it to a variable called *`ans8a`*.
#
# **HINT:** Use the *function [sort_values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html?highlight=sort_values#pandas.DataFrame.sort_values)*.

# %%
### GRADED
name     = ['john','mary','peter','jeff','bill','lisa','jose']
age      = [23,78,22,np.NaN,45,33,20]
gender   = ['M','F','M','M','M',np.NaN,'M']
state    = ['california','dc','california','dc','dc','california','texas']
num_pets = [5,1,0,5,2,2,3]

### YOUR SOLUTION HERE
df_8  = pd.DataFrame({'name':name,'age':age,'gender':gender,'state':state,'num_pets':num_pets})
ans8a = df_8.sort_values(by='age',ascending=False)

ans8a
# Out:
#     name   age gender       state  num_pets
# 1   mary  78.0      F          dc         1
# 4   bill  45.0      M          dc         2
# 5   lisa  33.0    NaN  california         2
# 0   john  23.0      M  california         5
# 2  peter  22.0      M  california         0
# 6   jose  20.0      M       texas         3
# 3   jeff   NaN      M          dc         5

# %% [markdown]
# ## Question 9
#
# *6 points*
#
# Remove the duplicates from the column *`state`* in *`df_8`* and assign the result to a new *dataframe* called *`ans9a`*.
#
# **HINT:** Use the *function [drop_duplicates](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html?highlight=drop_duplicates#pandas.DataFrame.drop_duplicates)*.

# %%
### GRADED
### YOUR SOLUTION HERE
ans9a = df_8.drop_duplicates(subset='state')
ans9a
# Out:
#    name   age gender       state  num_pets
# 0  john  23.0      M  california         5
# 1  mary  78.0      F          dc         1
# 6  jose  20.0      M       texas         3

# %% [markdown]
# ## Question 10
#
# *6 points*
#
# Remove all the missing values in *`df_8`* and assign the result to a new *dataframe* called *`ans10a`*.

# %%
### GRADED
### YOUR SOLUTION HERE
ans10a = df_8.dropna()
print(df_8)
ans10a
# Out:
#         age gender       state  num_pets
# name
# john   23.0      M  california         5
# mary   78.0      F          dc         1
# peter  22.0      M  california         0
# jeff    NaN      M          dc         5
# bill   45.0      M          dc         2
# lisa   33.0    NaN  california         2
# jose   20.0      M       texas         3
#         age gender       state  num_pets
# name
# john   23.0      M  california         5
# mary   78.0      F          dc         1
# peter  22.0      M  california         0
# bill   45.0      M          dc         2
# jose   20.0      M       texas         3

# %% [markdown]
# ## Question 11
#
# *5 points*
#
# What day of the week was October 24, 1990? Assign your answer as a *string* to *`ans11a`*.

# %%
### GRADED

### YOUR SOLUTION HERE
ans11a = pd.date_range(start='October 24, 1990', periods=1).day_name()[0]
ans11a
# Out:
# 'Wednesday'

# %% [markdown]
# ## Question 12
#
# *5 points*
#
# Use the *method* [is_leap_year](https://pandas.pydata.org/docs/reference/api/pandas.DatetimeIndex.is_leap_year.html) to check whether 2000 was a leap year. Assign your answer to *`ans12a.`*

# %%
### GRADED


### YOUR SOLUTION HERE
ans12a = pd.date_range(start='October 24, 2000', periods=1).is_leap_year[0]
ans12a
# Out:
# True

# %% [markdown]
# ## The Athletes Events Dataset
#
# In the next few questions, you will utilize the datasets `athlete_events.csv` and `regions.csv`.
#
# The datasets used throughout this activity are saved inside the folder `/data`.
#
# More information about this dataset can be found on Kaggle at this link:
#
# https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results
#
# **References:**
# Rgriffin. (2018). “120 years of Olympic history: athletes and results.” Accessed July 15, 2021.
# https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results .

# %% [markdown]
# Run the code cell below to load the datasets in `pandas`.

# %%
df_athletes = pd.read_csv("data/athlete_events.csv")
df_regions = pd.read_csv("data/noc_regions.csv")

# %% [markdown]
# Run the code cells below to visualize the first few rows in your *dataframe*.

# %%
df_athletes
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 15 columns]

# %%
df_regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %% [markdown]
# ### Question 13
# *10 points*
#
# Select all the rows from the *dataframe, `df_athletes`,* where `Year` is greater than 1980. Assign this *dataframe* to *`ans13a`*.
#
# Next, select all the rows in *`ans13a`* where `Team` is equal to `China`, `United States`, `Italy`, or `Spain`. Save your results in a *dataframe* called *`ans13b`*.
#
# **HINT**: To select only the desired countries, create a *list* containing the countries and use the *function* `isin` as follows:
#
# ```Python
# df.Team.isin([list_with_countries])
# ```

# %%
### GRADED

### YOUR SOLUTION HERE
year_filter = df_athletes['Year'] > 1980
ans13a = df_athletes[year_filter]
team_filter = ans13a['Team'].isin(['China','United States','Italy','Spain'])
ans13b = ans13a[team_filter]
ans13b
# Out:
#             ID                Name Sex   Age  Height  Weight           Team  \
# 0            1           A Dijiang   M  24.0   180.0    80.0          China
# 1            2            A Lamusi   M  23.0   170.0    60.0          China
# 10           6     Per Knut Aaland   M  31.0   188.0    75.0  United States
# 11           6     Per Knut Aaland   M  31.0   188.0    75.0  United States
# 12           6     Per Knut Aaland   M  31.0   188.0    75.0  United States
# ...        ...                 ...  ..   ...     ...     ...            ...
# 270850  135458            Rami Zur   M  27.0   175.0    77.0  United States
# 270851  135458            Rami Zur   M  31.0   175.0    77.0  United States
# 270852  135458            Rami Zur   M  31.0   175.0    77.0  United States
# 270891  135471  Jos Zurera Alberca   M  22.0   162.0    52.0          Spain
# 270892  135471  Jos Zurera Alberca   M  26.0   162.0    52.0          Spain
#
#         NOC        Games  Year  Season         City                 Sport  \
# 0       CHN  1992 Summer  1992  Summer    Barcelona            Basketball
# 1       CHN  2012 Summer  2012  Summer       London                  Judo
# 10      USA  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 11      USA  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 12      USA  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# ...     ...          ...   ...     ...          ...                   ...
# 270850  USA  2004 Summer  2004  Summer       Athina              Canoeing
# 270851  USA  2008 Summer  2008  Summer      Beijing              Canoeing
# 270852  USA  2008 Summer  2008  Summer      Beijing              Canoeing
# 270891  ESP  1988 Summer  1988  Summer        Seoul         Weightlifting
# 270892  ESP  1992 Summer  1992  Summer    Barcelona         Weightlifting
#
#                                                     Event Medal
# 0                             Basketball Men's Basketball   NaN
# 1                            Judo Men's Extra-Lightweight   NaN
# 10               Cross Country Skiing Men's 10 kilometres   NaN
# 11               Cross Country Skiing Men's 50 kilometres   NaN
# 12      Cross Country Skiing Men's 10/15 kilometres Pu...   NaN
# ...                                                   ...   ...
# 270850           Canoeing Men's Kayak Doubles, 500 metres   NaN
# 270851           Canoeing Men's Kayak Singles, 500 metres   NaN
# 270852         Canoeing Men's Kayak Singles, 1,000 metres   NaN
# 270891                   Weightlifting Men's Bantamweight   NaN
# 270892                   Weightlifting Men's Bantamweight   NaN
#
# [22533 rows x 15 columns]

# %% [markdown]
# ## Question 14
# *8 points*
#
# Use a left *join* to combine the *dataframes `df_athletes`* and *`df_regions`* into a new *dataframe* called *`ans14a`*. Set the column `NOC` as the key column.

# %%
### GRADED

### YOUR SOLUTION HERE
ans14a = pd.merge(df_athletes,df_regions,how='left',on='NOC')
ans14a
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal  \
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
#              region notes
# 0             China   NaN
# 1             China   NaN
# 2           Denmark   NaN
# 3           Denmark   NaN
# 4       Netherlands   NaN
# ...             ...   ...
# 271111       Poland   NaN
# 271112       Poland   NaN
# 271113       Poland   NaN
# 271114       Poland   NaN
# 271115       Poland   NaN
#
# [271116 rows x 17 columns]

# %%
df_regions
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %% [markdown]
# ## Question 15
# *6 points*
#
# *Pivot* the *dataframe `df_regions`*  by setting:
#
# - index = `region`
# - columns = `NOC`
# - values = `notes`
#
# Assign the new *dataframe* to *`ans15a`*.

# %%
### GRADED

### YOUR SOLUTION HERE

# YOUR CODE HERE
ans15a = pd.pivot(df_regions, index='region', values='notes', columns='NOC')
ans15a
# Out:
# NOC                      AFG  AHO  ALB  ALG  AND  ANG  ANT  ANZ  ARG  ARM  \
# region
# NaN                      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Afghanistan              NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Albania                  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Algeria                  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# American Samoa           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                      ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Virgin Islands, British  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Virgin Islands, US       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Yemen                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Zambia                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Zimbabwe                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# NOC                      ...  VIE  VIN  VNM  WIF          YAR  YEM  \
# region                   ...
# NaN                      ...  NaN  NaN  NaN  NaN          NaN  NaN
# Afghanistan              ...  NaN  NaN  NaN  NaN          NaN  NaN
# Albania                  ...  NaN  NaN  NaN  NaN          NaN  NaN
# Algeria                  ...  NaN  NaN  NaN  NaN          NaN  NaN
# American Samoa           ...  NaN  NaN  NaN  NaN          NaN  NaN
# ...                      ...  ...  ...  ...  ...          ...  ...
# Virgin Islands, British  ...  NaN  NaN  NaN  NaN          NaN  NaN
# Virgin Islands, US       ...  NaN  NaN  NaN  NaN          NaN  NaN
# Yemen                    ...  NaN  NaN  NaN  NaN  North Yemen  NaN
# Zambia                   ...  NaN  NaN  NaN  NaN          NaN  NaN
# Zimbabwe                 ...  NaN  NaN  NaN  NaN          NaN  NaN
#
# NOC                              YMD  YUG  ZAM  ZIM
# region
# NaN                              NaN  NaN  NaN  NaN
# Afghanistan                      NaN  NaN  NaN  NaN
# Albania                          NaN  NaN  NaN  NaN
# Algeria                          NaN  NaN  NaN  NaN
# American Samoa                   NaN  NaN  NaN  NaN
# ...                              ...  ...  ...  ...
# Virgin Islands, British          NaN  NaN  NaN  NaN
# Virgin Islands, US               NaN  NaN  NaN  NaN
# Yemen                    South Yemen  NaN  NaN  NaN
# Zambia                           NaN  NaN  NaN  NaN
# Zimbabwe                         NaN  NaN  NaN  NaN
#
# [207 rows x 230 columns]

# %% [markdown]
# ## Question 16
# *9 points*
#
# Group the entries of the *dataframe `df_athletes`* by the columns `"Season"` and `"Medal"`. Assign the new *dataframe* to *`ans16a`*.
#
# Answer the following question:
#
# In which Olympic games did the first group of athletes participate?
# - a) 2014 Winter
# - b) 1920 Summer
# - c) 1994 Summer
# - d) 1920 Winter
#
# Assign the letter of the correct answer as a *string* to *`ans16b`*.
#
# For instance, if you believe the correct answer is *a) 2014 Winter*, your answer would be *`ans16b = 'a'`*.

# %%
### GRADED

### YOUR SOLUTION HERE
ans16a = df_athletes.groupby(['Season','Medal'])
ans16b =  'b'
ans16a.first()
# Out:
#                ID                      Name Sex   Age  Height  Weight  \
# Season Medal
# Summer Bronze  15      Arvo Ossian Aaltonen   M  30.0   175.0    64.0
#        Gold     4      Edgar Lindenau Aabye   M  34.0   175.0    64.0
#        Silver  25          Alf Lied Aanning   M  24.0   189.0    72.0
# Winter Bronze  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
#        Gold    20        Kjetil Andr Aamodt   M  20.0   176.0    85.0
#        Silver  20        Kjetil Andr Aamodt   M  22.0   176.0    85.0
#
#                          Team  NOC        Games  Year         City  \
# Season Medal
# Summer Bronze         Finland  FIN  1920 Summer  1920    Antwerpen
#        Gold    Denmark/Sweden  DEN  1900 Summer  1900        Paris
#        Silver          Norway  NOR  1920 Summer  1920    Antwerpen
# Winter Bronze         Finland  FIN  2014 Winter  2014        Sochi
#        Gold            Norway  NOR  1992 Winter  1992  Albertville
#        Silver          Norway  NOR  1994 Winter  1994  Lillehammer
#
#                        Sport                                          Event
# Season Medal
# Summer Bronze       Swimming         Swimming Men's 200 metres Breaststroke
#        Gold       Tug-Of-War                    Tug-Of-War Men's Tug-Of-War
#        Silver     Gymnastics  Gymnastics Men's Team All-Around, Free System
# Winter Bronze     Ice Hockey                    Ice Hockey Men's Ice Hockey
#        Gold    Alpine Skiing                    Alpine Skiing Men's Super G
#        Silver  Alpine Skiing                   Alpine Skiing Men's Downhill

# %% [markdown]
# ### Question 17
# *10 points*
#
# Perform the following aggregation operations on *`df_athletes`*:
#
# - Compute the `max` and the `min` on the column *`Age`*.
# - Compute the `mean` on the column *`Weight`*.
#
# Assign the new *dataframe* to *`ans17a`*.
#
# **HINT:** Use the *function [aggregate()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.aggregate.html)* with the following syntax:
#
# ```Python
#
# df.aggregate({first_column:['max', 'min'], second_column:['mean']})
#
# ```

# %%
### GRADED

### YOUR SOLUTION HERE
ans17a = df_athletes.aggregate({'Age': ['min', 'max'],'Weight':['mean']})
ans17a
# Out:
#        Age     Weight
# min   10.0        NaN
# max   97.0        NaN
# mean   NaN  70.702393
